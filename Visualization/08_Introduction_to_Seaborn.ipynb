# %%
import seaborn as sns #Easiler, high level control like python, prettier graphs with low ammount of code, integrates with numpy eaily
import numpy as np
import matplotlib.pyplot as plt #Low level control like C or assembly, high amount of code

# %%
sns.set_theme(style="darkgrid")

# %%
x = np.array([1,2,3,767,14,25,125,36,45])
y = np.sin(x)
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >
